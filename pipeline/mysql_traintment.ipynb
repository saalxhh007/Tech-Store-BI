# %%
import mysql.connector as cn
import pandas as pd

# %%
# Connecting to database
try:
    db = cn.connect(
    user="student_user_4ing",
    password="bi_guelma_2025",
    host="boughida.com",
    database="techstore_erp"
)
except cn.Error as e:
    print(e)

# %%
# selecting tables
q = "SELECT * FROM table_sales"
q2 = "SELECT * FROM table_products"
# cleaning data for sales_table
sales_df = pd.read_sql(q, db)
products_df = pd.read_sql(q2, db)
# confirm non nullability
sales_df.isnull().sum()
products_df.isnull().sum()
# Out:
# C:\Users\ilisa\AppData\Local\Temp\ipykernel_30440\3698565664.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales_df = pd.read_sql(q, db)
# C:\Users\ilisa\AppData\Local\Temp\ipykernel_30440\3698565664.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   products_df = pd.read_sql(q2, db)
# Product_ID      0
# Product_Name    0
# SubCat_ID       0
# Unit_Price      0
# Unit_Cost       0
# dtype: int64

# %%
print(sales_df[sales_df["Quantity"] <= 0])
print(sales_df[sales_df["Total_Revenue"] <= 0])
# Out:
# Empty DataFrame
# Columns: [Trans_ID, Date, Store_ID, Product_ID, Customer_ID, Quantity, Total_Revenue]
# Index: []
# Empty DataFrame
# Columns: [Trans_ID, Date, Store_ID, Product_ID, Customer_ID, Quantity, Total_Revenue]
# Index: []

# %%
sales_df.drop_duplicates(inplace=True)

# %%
# if it has an empty revenue i will get the product price via the id and then prod_price * quantity
# if no quantity is there i wil assume it is one

# %%
sales_df['Date'] = pd.to_datetime(sales_df['Date'], errors='coerce', format='%Y-%m-%d')
